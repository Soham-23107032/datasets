# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

iris = sns.load_dataset('iris')

#pie chart

counts = iris['species'].value_counts()

plt.figure(figsize = (8,8))
plt.pie(counts, labels=species_counts.index, autopct='%1.1f%%', startangle=140)
plt.title("PIE")
plt.show()

# %%
#bar plot

means = iris.groupby('species').mean()

means.plot(kind = 'bar' , figsize = (10,6))

plt.title('Average Measurements of Iris Features by Species')
plt.ylabel('Average Measurement (cm)')
plt.xlabel('Species')
plt.show()
